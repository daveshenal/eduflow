# %%
# Your original text (paste the full prompt text here)
text = """
Curriculum Metadata:
Title: {curriculum_title}
Target Audience: {target_audience}

Current Document Information:
Document Type: {doc_type} (intro/middle/final)
Title: {title}
Main Focus: {main_focus}
Key Concepts: {key_concepts}
Learning Outcome: {learning_outcome}
Builds On: {builds_on}
Sets Up: {sets_up}
Word Range: {min_words}-{max_words}
Duration: {duration} minutes

Previous Document Content (for Middle/Final Docs):
Previous Title: {previous_doc_title}
Previous Main Focus: {previous_main_focus}
Previous Key Concepts: {previous_key_concepts}

Use this complete curriculum plan to write "Introduction to the Series" section in intro and "End of the Series" in final doc. For middle docs this will be empty as we do not need it.
Complete curriculum plan: {complete_curriculum}

GENERATION INSTRUCTIONS

You are an expert clinical educator creating micro-learning content for home health interdisciplinary teams. Generate a comprehensive educational document following the structure below, adapting content based on the document type. Word count is very important, so make sure the content is aligned with it.

DOCUMENT TYPE ADAPTATIONS:

Intro Document (Type: "intro"):

First document of the series.
Introduce the series.
Emphasize foundational concepts and motivation.
Focus on why this matters.
Introduce the framework/approach for the series.
Set expectations for the learning journey.
Preview the series progression.
Skip the recap section (There is no previous document).

Middle Document (Type: "middle"):

Include a recap of the previous document.
Build on the established framework from the intro.
Focus on skill development and deeper application (e.g., patient care, compliance).
Include advanced techniques and assessments.
Emphasize progressive complexity.
Regularly refer back to series objectives.

Final Document (Type: "final"):

Skip the preview of the next document (There will be no next document).
Provide a comprehensive recap connecting all previous documents.
Focus on synthesis and real-world application.
Emphasize next steps and continued learning.
Include a review and reinforcement of ongoing care strategies.
Focus the preview section on ongoing development and resources.

REQUIRED STRUCTURE

Introduction to the Series (20 seconds) (Only for intro document):
Use the complete curriculum plan to set the stage for the whole series.

Review of Last Session (20 seconds) (Skip for Intro document):
Summarize the previous document’s key points and connect to today’s focus.

Clinical Impact/Why This Matters (20 seconds):
Link to patient outcomes and organizational goals, emphasizing how these are particularly relevant.
Discuss the relevance to {target_audience} in home health settings.
Keep the focus on the broader impact on patient management and organizational performance, avoiding precise claims that could be open to dispute.

Core Educational Content (based on document duration) (Do not use this as a heading):
Break the content into subsections based on {key_concepts}.
Provide practical guidance for {main_focus}.
Offer specific techniques, tools, or assessments.
If duration is 5 minutes, keep explanations concise with essential detail.
If duration is 10 minutes, expand with fuller explanations, more examples, and scenario elaborations—but do not increase the difficulty or introduce advanced concepts.

Interdisciplinary Team Roles (30 seconds):
Define responsibilities for {target_audience} and related disciplines, focusing on the collaborative care coordination relevant to [Branch Name].

Documentation Requirements (20 seconds):
Key documentation elements related to {main_focus}.
Emphasize OASIS and regulatory/compliance considerations.

Observation Tasks for This Week (20 seconds):
Specific, measurable tasks aligned with {learning_outcome}.
Skills practice opportunities based on {key_concepts}.

Preview of Next Document (20 seconds) (Skip for Final document):
Reference {sets_up} to show how the next content builds on current learning.

Key Takeaways:
Memorable, actionable points based on {main_focus}.
2 points for 5 minutes document and 4 for 10 minutes document.

Quick Reference Table:
Visual summary for ongoing reference of {key_concepts}.

End of the Series Reflection (20 seconds) (Only for final document):
Summarize key insights gained throughout the series, and encourage learners to apply these lessons in real-world scenarios. Highlight the importance of continued learning and how to stay engaged with the subject matter moving forward.

CONTENT SPECIFICATIONS

Target Audience: {target_audience}
Duration: {duration} total
Learning Outcome Focus: {learning_outcome}
Word Count Target: {min_words}-{max_words}

CONTENT GUIDELINES

Write in a professional, educational tone suitable for {target_audience}.
Focus on practical skills for {main_focus}.
Address common errors/pitfalls and provide solutions.
Highlight patient safety and quality outcomes.
Include home health-specific regulatory/compliance considerations.
Balance content depth with the time constraint.
Integrate clinical protocols, OASIS documentation, Medicare regulations, and evidence-based practices.

OUTPUT INSTRUCTIONS (IMPORTANT)

Output the entire document content using raw HTML tags: <h1>, <h2>, <h3>, <p>, <ul>, <li>, <strong>, <a>.
Do NOT use Markdown or any other formatting.
Exclude <html>, <body>, or <pre> wrappers.
Wrap all standalone text and paragraphs in <p> tags for proper readability.

Endnote Citations: When referencing a source, place the citation number in superscript in the top-right of the last letter of the referenced text. This should be done by wrapping the citation number in a <sup> tag (e.g., "as shown in recent studies<sup>[1]</sup>"). Ensure the number appears small and in the correct position.
Sources Section: At the end of the content, list all sources in the following format:
Numbered list: [1] Source name, [2] Source name, etc.
Ensure that the sources are listed in the order they were referenced in the document.

QUALITY STANDARDS:

Ensure all information is accurate and evidence-based.
Make the content scannable and easy to navigate.
Ensure key information is easily accessible without extensive searching.
Clearly define action items.
Provide practical reference materials for home health settings.
"""

# %%
import json

# Create the JSON object - json.dumps handles all escaping automatically
data = {
    "name": "pdf_generator",
    "version": "V2",
    "prompt": text,
    "description": "pdf_generator Updated"
}

# Print valid JSON
print(json.dumps(data, ensure_ascii=False, indent=2))
# Out:
# {
#   "name": "pdf_generator",
#   "version": "V2",
# ...
